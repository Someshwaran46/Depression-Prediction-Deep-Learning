# %%
import pandas as pd
df=pd.read_csv("/Users/somesh-19583/Desktop/Health Care/playground-series-s4e11/Cleaned_Data.csv")
df.sample(5)
# Out:
#         Gender   Age         City Working Professional or Student  Profession  \
# 139719    Male  49.0      Chennai            Working Professional       Pilot
# 105071    Male  48.0      Lucknow            Working Professional  Pharmacist
# 95370   Female  31.0       Jaipur                         Student     Teacher
# 13859   Female  51.0     Varanasi            Working Professional     Teacher
# 43774     Male  37.0  Vasai-Virar            Working Professional     Chemist
#
#         Work Pressure  Job Satisfaction     Sleep Duration Dietary Habits  \
# 139719       5.000000          2.000000  Less than 5 hours      Unhealthy
# 105071       4.000000          4.000000  Less than 5 hours       Moderate
# 95370        3.347926          2.806452  Less than 5 hours        Healthy
# 13859        1.000000          4.000000          7-8 hours        Healthy
# 43774        2.000000          3.000000  More than 8 hours       Moderate
#
#          Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 139719      PhD                                    No               0.0
# 105071  B.Pharm                                    No               2.0
# 95370      B.Ed                                   Yes               2.0
# 13859       LLM                                   Yes               2.0
# 43774   B.Pharm                                    No               8.0
#
#         Financial Stress Family History of Mental Illness  Depression
# 139719               5.0                               No           0
# 105071               1.0                              Yes           0
# 95370                3.0                              Yes           0
# 13859                3.0                              Yes           0
# 43774                2.0                              Yes           0

# %% [markdown]
# Exploratory Data Analysis

# %%
numerical_cols = ['Age', 'Work Pressure', 'Job Satisfaction', 'Work/Study Hours', 'Financial Stress']

categorical_cols=['Gender', 'City', 'Working Professional or Student', 'Profession', 'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Family History of Mental Illness', 'Depression']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# -------------------- NUMERICAL FEATURES EDA --------------------

# Plotting Numerical Distributions
for col in numerical_cols:
    plt.figure(figsize=(10, 4))
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# -------------------- CATEGORICAL FEATURES EDA --------------------
print("\n--- Categorical Features EDA ---")
for col in categorical_cols:
    print(f"\nValue counts for {col}:")
    print(df[col].value_counts())

# Plotting Categorical Distributions
for col in categorical_cols:
    plt.figure(figsize=(12, 5))
    order = df[col].value_counts().index
    sns.countplot(data=df, x=col, order=order, palette='Set2')
    plt.title(f'Count Plot of {col}')
    plt.xticks(rotation=45, ha='right')
    plt.grid(True)
    plt.show()

# -------------------- CORRELATION HEATMAP --------------------
if len(numerical_cols) > 1:
    plt.figure(figsize=(12, 8))
    corr = df[numerical_cols].corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Correlation Heatmap between Numerical Features')
    plt.show()
# Out:
# --- Categorical Features EDA ---
#
# Value counts for Gender:
# Gender
# Male      77459
# Female    63231
# Name: count, dtype: int64
#
# Value counts for City:
# City
# Kalyan           6603
# Patna            5938
# Vasai-Virar      5777
# Kolkata          5694
# Ahmedabad        5620
# Meerut           5545
# Ludhiana         5229
# Pune             5212
# Rajkot           5210
# Visakhapatnam    5176
# Srinagar         5072
# Mumbai           4968
# Indore           4874
# Agra             4684
# Surat            4636
# Varanasi         4612
# Vadodara         4574
# Hyderabad        4494
# Kanpur           4398
# Jaipur           4329
# Thane            4289
# Lucknow          4280
# Nagpur           4209
# Bangalore        4123
# Chennai          4044
# Ghaziabad        3620
# Delhi            3593
# Bhopal           3475
# Faridabad        3268
# Nashik           3143
# Gurgaon             1
# Name: count, dtype: int64
#
# Value counts for Working Professional or Student:
# Working Professional or Student
# Working Professional    112794
# Student                  27896
# Name: count, dtype: int64
#
# Value counts for Profession:
# Profession
# Teacher                   61841
# Content Writer             7814
# HR Manager                 5086
# Architect                  4370
# Consultant                 4228
# Pharmacist                 3893
# Doctor                     3255
# Business Analyst           3161
# Entrepreneur               2968
# Chemist                    2967
# Chef                       2862
# Educational Consultant     2852
# Data Scientist             2390
# Researcher                 2328
# Lawyer                     2212
# Customer Support           2055
# Marketing Manager          1976
# Pilot                      1913
# Travel Consultant          1860
# Plumber                    1748
# Sales Executive            1739
# Manager                    1737
# Judge                      1712
# Electrician                1582
# Financial Analyst          1574
# Software Engineer          1510
# Civil Engineer             1469
# UX/UI Designer             1452
# Digital Marketer           1372
# Accountant                 1339
# Mechanical Engineer        1177
# Graphic Designer           1163
# Research Analyst            690
# Investment Banker           393
# Family Consultant             1
# Medical Doctor                1
# Name: count, dtype: int64
#
# Value counts for Sleep Duration:
# Sleep Duration
# Less than 5 hours    38793
# 7-8 hours            36985
# More than 8 hours    32725
# 5-6 hours            32138
# 3-4 hours               12
# 6-7 hours                8
# 4-5 hours                7
# 4-6 hours                5
# 2-3 hours                5
# 6-8 hours                4
# 10-11 hours              2
# 8-9 hours                2
# 9-11 hours               2
# 1-2 hours                1
# 8 hours                  1
# Name: count, dtype: int64
#
# Value counts for Dietary Habits:
# Dietary Habits
# Moderate     49715
# Unhealthy    46235
# Healthy      44740
# Name: count, dtype: int64
#
# Value counts for Degree:
# Degree
# B.Ed       18384
# B.Arch     10875
# B.Com       8577
# BHM         7274
# BSc         6833
# B.Pharm     5885
# BCA         5767
# M.Ed        5668
# MCA         5393
# BBA         5030
# MSc         4879
# LLM         4709
# LLB         4661
# M.Tech      4554
# M.Pharm     4536
# B.Tech      4499
# MBA         3817
# BA          3750
# ME          3631
# MD          3383
# MHM         3286
# MBBS        3106
# BE          3104
# PhD         3103
# M.Com       3094
# MA          2887
# M.Arch         5
# Name: count, dtype: int64
#
# Value counts for Have you ever had suicidal thoughts ?:
# Have you ever had suicidal thoughts ?
# No     71132
# Yes    69558
# Name: count, dtype: int64
#
# Value counts for Family History of Mental Illness:
# Family History of Mental Illness
# No     70753
# Yes    69937
# Name: count, dtype: int64
#
# Value counts for Depression:
# Depression
# 0    115127
# 1     25563
# Name: count, dtype: int64
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
# /var/folders/wx/4rg4nk210z1b7k5t2v6q8gj40000gp/T/ipykernel_52962/2502256658.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=order, palette='Set2')
